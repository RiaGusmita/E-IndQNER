# %%
# !pwd
# Out:
# /local/upb/users/a/asepff/profiles/unix/cs/E-IndQNER/new-scripts

# %%
import json
import pandas as pd
from collections import defaultdict, namedtuple, Counter

# Namedtuple to store evaluation metrics
Metrics = namedtuple('Metrics', 'tp fp fn prec rec fscore')

# Tokenize the label and prediction into word/tag pairs
def tokenize_label_pred(text):
    tokens = []
    for token in text.split():
        if "//" in token:
            token = token.replace("//", "/")
        if len(token.split("/")) == 2:
            r = (token.split('/')[-2], token.split('/')[-1])
            tokens.append(r)
        else:
            #Split into two results
            #print(token)
            if len(token.split("/"))==3:
                r1 = (token.split("/")[0], token.split("/")[1][0])
                r2 = (token.split("/")[1][1:], token.split("/")[2])
                tokens.append(r1)
                tokens.append(r2)
            else:
                print("uncover", token)
    return tokens

# Function to calculate precision, recall, and F1 score
def calculate_metrics(correct, guessed, total):
    tp, fp, fn = correct, guessed - correct, total - correct
    # Precision, Recall, F1 Score calculations
    p = 0 if tp + fp == 0 else tp / (tp + fp)
    r = 0 if tp + fn == 0 else tp / (tp + fn)
    f = 0 if p + r == 0 else 2 * p * r / (p + r)
    return Metrics(tp, fp, fn, p, r, f)

# File paths for test labels and predictions
test_labels_path_new = '../new-datasets/updated_test_set_final.txt'
results_path_new = 'results-gpt.json'

# Read ground truth labels
with open(test_labels_path_new, 'r', encoding='utf-8') as f:
    ground_truth = f.readlines()

# Read predictions from the model
with open(results_path_new, 'r', encoding='utf-8') as f:
    predictions = json.load(f)

# Lists to store precision, recall, F1 for each instance
precs, recs, fscores = [], [], []

# Iterate over each label and corresponding prediction
for num, label in enumerate(ground_truth):
    # Initialize counters for correct matches and errors
    correct = 0
    id_ = str(num + 1)  # Key in the predictions JSON
    print(f"######### Instance {id_} ##############")
    
    # Tokenize label and prediction
    label_tokens = tokenize_label_pred(label.strip())
    prediction_tokens = tokenize_label_pred(predictions[id_].strip())

    # Count frequencies of tokens in label and prediction
    label_token_counts = Counter(label_tokens)
    prediction_token_counts = Counter(prediction_tokens)
    
    # Print for debugging
    print("Label Tokens:\n", label_tokens)
    print("prediction", predictions[id_])
    print("Prediction Tokens:\n", prediction_tokens)

    total = len(label_tokens)  # Total actual tokens
    guessed = len(prediction_tokens)  # Total predicted tokens

    # Track seen tokens from the prediction to avoid duplicates
    seen_in_prediction = []
    
    for pred_token in prediction_tokens:
        # Only count correct if the frequency in prediction <= frequency in label
        if pred_token in label_tokens and prediction_token_counts[pred_token] <= label_token_counts[pred_token]:
            if seen_in_prediction.count(pred_token) < label_token_counts[pred_token]:
                correct += 1  # Count true positives
                seen_in_prediction.append(pred_token)  # Mark as seen

    print("correct:\n", seen_in_prediction)
    # Final counts: TP = correct, FP = guessed - correct, FN = total - correct
    print(f"Correct: {correct}, Guessed: {guessed}, Total: {total}")
    metrics = calculate_metrics(correct, guessed, total)
    print(metrics)
    
    # Append the precision, recall, and F1 score for this instance
    precs.append(metrics.prec)
    recs.append(metrics.rec)
    fscores.append(metrics.fscore)

# Compute averages over all instances
avg_precs = sum(precs) / len(precs)
avg_recs = sum(recs) / len(recs)
avg_fscores = sum(fscores) / len(fscores)

# Print final averages
print("Total records in the test set:", len(ground_truth))
print("Average Precision:", avg_precs)
print("Average Recall:", avg_recs)
print("Average F1 Score:", avg_fscores)
# Out:
# ######### Instance 1 ##############
# Label Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'O'), (')', 'O'), ('.', 'O')]
# prediction Tidak/O ada/O sesuatu/O yang/O lebih/O kecil/O dan/O yang/O lebih/O besar/O daripada/O itu/O ,/O kecuali/O semua/O tercatat/O dalam/O kitab/O yang/O nyata/O (/O Lauh/O Mahfuz/O )/O ./O
# Prediction Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'O'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Tidak', 'O'), ('ada', 'O'), ('sesuatu', 'O'), ('yang', 'O'), ('lebih', 'O'), ('kecil', 'O'), ('dan', 'O'), ('yang', 'O'), ('lebih', 'O'), ('besar', 'O'), ('daripada', 'O'), ('itu', 'O'), (',', 'O'), ('kecuali', 'O'), ('semua', 'O'), ('tercatat', 'O'), ('dalam', 'O'), ('kitab', 'O'), ('yang', 'O'), ('nyata', 'O'), ('(', 'O'), ('Lauh', 'O'), ('Mahfuz', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 25, Guessed: 25, Total: 25
# Metrics(tp=25, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 2 ##############
# Label Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# prediction Ketahuilah/O bahwa/O sesungguhnya/O (/O bagi/O )/O para/O wali/O Allah/Allah itu/O tidak/O ada/O rasa/O takut/O yang/O menimpa/O mereka/O dan/O mereka/O pun/O tidak/O bersedih/O ./O
# Prediction Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# correct:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('(', 'O'), ('bagi', 'O'), (')', 'O'), ('para', 'O'), ('wali', 'O'), ('Allah', 'Allah'), ('itu', 'O'), ('tidak', 'O'), ('ada', 'O'), ('rasa', 'O'), ('takut', 'O'), ('yang', 'O'), ('menimpa', 'O'), ('mereka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('pun', 'O'), ('tidak', 'O'), ('bersedih', 'O'), ('.', 'O')]
# Correct: 23, Guessed: 23, Total: 23
# Metrics(tp=23, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 3 ##############
# Label Tokens:
#  [('(', 'O'), ('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# prediction (/O Mereka/O adalah/O )/O orang-orang/O yang/O beriman/O dan/O selalu/O bertakwa/O ./O
# Prediction Tokens:
#  [('(', 'O'), ('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# correct:
#  [('(', 'O'), ('Mereka', 'O'), ('adalah', 'O'), (')', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('beriman', 'O'), ('dan', 'O'), ('selalu', 'O'), ('bertakwa', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 11, Total: 11
# Metrics(tp=11, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 4 ##############
# Label Tokens:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'O'), ('.', 'O')]
# prediction Bagi/O mereka/O berita/O gembira/O di/O dalam/O kehidupan/O di/O dunia/O dan/O di/O akhirat/O ./O
# Prediction Tokens:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'O'), ('.', 'O')]
# correct:
#  [('Bagi', 'O'), ('mereka', 'O'), ('berita', 'O'), ('gembira', 'O'), ('di', 'O'), ('dalam', 'O'), ('kehidupan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('di', 'O'), ('akhirat', 'O'), ('.', 'O')]
# Correct: 13, Guessed: 13, Total: 13
# Metrics(tp=13, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 5 ##############
# Label Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# prediction Tidak/O ada/O perubahan/O bagi/O kalimat-kalimat/O (/O ketetapan/O dan/O janji/O )/O Allah/Allah ./O
# Prediction Tokens:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# correct:
#  [('Tidak', 'O'), ('ada', 'O'), ('perubahan', 'O'), ('bagi', 'O'), ('kalimat-kalimat', 'O'), ('(', 'O'), ('ketetapan', 'O'), ('dan', 'O'), ('janji', 'O'), (')', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Correct: 12, Guessed: 12, Total: 12
# Metrics(tp=12, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 6 ##############
# Label Tokens:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# prediction Demikian/O itulah/O kemenangan/O yang/O agung/O ./O
# Prediction Tokens:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# correct:
#  [('Demikian', 'O'), ('itulah', 'O'), ('kemenangan', 'O'), ('yang', 'O'), ('agung', 'O'), ('.', 'O')]
# Correct: 6, Guessed: 6, Total: 6
# Metrics(tp=6, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 7 ##############
# Label Tokens:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# prediction Janganlah/O engkau/O (/O Nabi/O Muhammad/Messenger )/O sedih/O oleh/O perkataan/O mereka/O ./O
# Prediction Tokens:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# correct:
#  [('Janganlah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('sedih', 'O'), ('oleh', 'O'), ('perkataan', 'O'), ('mereka', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 11, Total: 11
# Metrics(tp=11, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 8 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# prediction Sesungguhnya/O kekuasaan/O itu/O seluruhnya/O milik/O Allah/Allah ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('kekuasaan', 'O'), ('itu', 'O'), ('seluruhnya', 'O'), ('milik', 'O'), ('Allah', 'Allah'), ('.', 'O')]
# Correct: 7, Guessed: 7, Total: 7
# Metrics(tp=7, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 9 ##############
# Label Tokens:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# prediction Dia/O Maha/O Mendengar/O lagi/O Maha/O Mengetahui/O ./O
# Prediction Tokens:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# correct:
#  [('Dia', 'O'), ('Maha', 'O'), ('Mendengar', 'O'), ('lagi', 'O'), ('Maha', 'O'), ('Mengetahui', 'O'), ('.', 'O')]
# Correct: 7, Guessed: 7, Total: 7
# Metrics(tp=7, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 10 ##############
# Label Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# prediction Ketahuilah/O bahwa/O sesungguhnya/O milik/O Allahlah/O siapa/O yang/O ada/O di/O langit/O dan/O siapa/O yang/O ada/O di/O bumi/AstronomicalBody ./O
# Prediction Tokens:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# correct:
#  [('Ketahuilah', 'O'), ('bahwa', 'O'), ('sesungguhnya', 'O'), ('milik', 'O'), ('Allahlah', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('siapa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# Correct: 17, Guessed: 17, Total: 17
# Metrics(tp=17, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 11 ##############
# Label Tokens:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O'), (')', 'O'), ('.', 'O')]
# prediction Orang-orang/O yang/O menyeru/O sekutu-sekutu/O selain/O Allah/Allah tidaklah/O mengikuti/O (/O suatu/O kebenaran/O )/O ./O
# Prediction Tokens:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O'), (')', 'O'), ('.', 'O')]
# correct:
#  [('Orang-orang', 'O'), ('yang', 'O'), ('menyeru', 'O'), ('sekutu-sekutu', 'O'), ('selain', 'O'), ('Allah', 'Allah'), ('tidaklah', 'O'), ('mengikuti', 'O'), ('(', 'O'), ('suatu', 'O'), ('kebenaran', 'O'), (')', 'O'), ('.', 'O')]
# Correct: 13, Guessed: 13, Total: 13
# Metrics(tp=13, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 12 ##############
# Label Tokens:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# prediction Mereka/O hanya/O mengikuti/O persangkaan/O belaka/O dan/O mereka/O hanyalah/O menduga-duga/O ./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('hanya', 'O'), ('mengikuti', 'O'), ('persangkaan', 'O'), ('belaka', 'O'), ('dan', 'O'), ('mereka', 'O'), ('hanyalah', 'O'), ('menduga-duga', 'O'), ('.', 'O')]
# Correct: 10, Guessed: 10, Total: 10
# Metrics(tp=10, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 13 ##############
# Label Tokens:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# prediction Dialah/O yang/O menjadikan/O malam/O bagimu/O agar/O kamu/O beristirahat/O padanya/O dan/O (/O menjadikan/O )/O siang/O terang/O benderang/O ./O
# Prediction Tokens:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# correct:
#  [('Dialah', 'O'), ('yang', 'O'), ('menjadikan', 'O'), ('malam', 'O'), ('bagimu', 'O'), ('agar', 'O'), ('kamu', 'O'), ('beristirahat', 'O'), ('padanya', 'O'), ('dan', 'O'), ('(', 'O'), ('menjadikan', 'O'), (')', 'O'), ('siang', 'O'), ('terang', 'O'), ('benderang', 'O'), ('.', 'O')]
# Correct: 17, Guessed: 17, Total: 17
# Metrics(tp=17, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 14 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O pada/O yang/O demikian/O itu/O benar-benar/O terdapat/O tanda-tanda/O (/O kebesaran/O Allah/Allah )/O bagi/O kaum/O yang/O (/O mau/O )/O mendengar/O ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('pada', 'O'), ('yang', 'O'), ('demikian', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('terdapat', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kebesaran', 'O'), ('Allah', 'Allah'), (')', 'O'), ('bagi', 'O'), ('kaum', 'O'), ('yang', 'O'), ('(', 'O'), ('mau', 'O'), (')', 'O'), ('mendengar', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 20, Total: 20
# Metrics(tp=20, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 15 ##############
# Label Tokens:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# prediction Mereka/O (/O yang/O menyekutukan/O Allah/Allah )/O berkata/O ,/O “/O Allah/Allah mengangkat/O anak/O ./O
# Prediction Tokens:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# correct:
#  [('Mereka', 'O'), ('(', 'O'), ('yang', 'O'), ('menyekutukan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Allah', 'Allah'), ('mengangkat', 'O'), ('anak', 'O'), ('.', 'O')]
# Correct: 13, Guessed: 13, Total: 13
# Metrics(tp=13, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 16 ##############
# Label Tokens:
#  [('”', 'O'), ('Maha', 'O'), ('Suci', 'O'), ('Dia', 'O'), ('.', 'O')]
# prediction ”/O Maha/O Suci/O Dia/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Maha', 'O'), ('Suci', 'O'), ('Dia', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Maha', 'O'), ('Suci', 'O'), ('Dia', 'O'), ('.', 'O')]
# Correct: 5, Guessed: 5, Total: 5
# Metrics(tp=5, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 17 ##############
# uncover Yang
# uncover Maha
# uncover Yang
# uncover Maha
# Label Tokens:
#  [('Dialah', 'O'), ('Kaya', 'Allah'), ('.', 'O')]
# prediction Dialah/O Yang Maha Kaya/Allah ./O
# Prediction Tokens:
#  [('Dialah', 'O'), ('Kaya', 'Allah'), ('.', 'O')]
# correct:
#  [('Dialah', 'O'), ('Kaya', 'Allah'), ('.', 'O')]
# Correct: 3, Guessed: 3, Total: 3
# Metrics(tp=3, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 18 ##############
# Label Tokens:
#  [('Milik-Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# prediction Milik-Nyalah/O apa/O yang/O ada/O di/O langit/O dan/O apa/O yang/O ada/O di/O bumi/AstronomicalBody ./O
# Prediction Tokens:
#  [('Milik-Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# correct:
#  [('Milik-Nyalah', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('langit', 'O'), ('dan', 'O'), ('apa', 'O'), ('yang', 'O'), ('ada', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('.', 'O')]
# Correct: 13, Guessed: 13, Total: 13
# Metrics(tp=13, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 19 ##############
# Label Tokens:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# prediction Kamu/O tidak/O mempunyai/O alasan/O kuat/O tentang/O ini/O ./O
# Prediction Tokens:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# correct:
#  [('Kamu', 'O'), ('tidak', 'O'), ('mempunyai', 'O'), ('alasan', 'O'), ('kuat', 'O'), ('tentang', 'O'), ('ini', 'O'), ('.', 'O')]
# Correct: 8, Guessed: 8, Total: 8
# Metrics(tp=8, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 20 ##############
# Label Tokens:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# prediction Pantaskah/O kamu/O mengatakan/O tentang/O Allah/Allah apa/O yang/O tidak/O kamu/O ketahui/O ?/O Katakanlah/O (/O Nabi/O Muhammad/Messenger )/O ,/O “/O Sesungguhnya/O orang-orang/O yang/O mengada-adakan/O kebohongan/O terhadap/O Allah/Allah tidak/O akan/O beruntung/O ./O
# Prediction Tokens:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# correct:
#  [('Pantaskah', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('tentang', 'O'), ('Allah', 'Allah'), ('apa', 'O'), ('yang', 'O'), ('tidak', 'O'), ('kamu', 'O'), ('ketahui', 'O'), ('?', 'O'), ('Katakanlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mengada-adakan', 'O'), ('kebohongan', 'O'), ('terhadap', 'O'), ('Allah', 'Allah'), ('tidak', 'O'), ('akan', 'O'), ('beruntung', 'O'), ('.', 'O')]
# Correct: 29, Guessed: 29, Total: 29
# Metrics(tp=29, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 21 ##############
# Label Tokens:
#  [('”', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# prediction ”/O (/O Bagi/O mereka/O )/O kesenangan/O (/O sesaat/O )/O ketika/O di/O dunia/O ,/O selanjutnya/O kepada/O Kamilah/O tempat/O mereka/O kembali/O ,/O kemudian/O Kami/O jadikan/O mereka/O merasakan/O azab/O yang/O keras/O karena/O mereka/O selalu/O kufur/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('(', 'O'), ('Bagi', 'O'), ('mereka', 'O'), (')', 'O'), ('kesenangan', 'O'), ('(', 'O'), ('sesaat', 'O'), (')', 'O'), ('ketika', 'O'), ('di', 'O'), ('dunia', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('kepada', 'O'), ('Kamilah', 'O'), ('tempat', 'O'), ('mereka', 'O'), ('kembali', 'O'), (',', 'O'), ('kemudian', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('merasakan', 'O'), ('azab', 'O'), ('yang', 'O'), ('keras', 'O'), ('karena', 'O'), ('mereka', 'O'), ('selalu', 'O'), ('kufur', 'O'), ('.', 'O')]
# Correct: 33, Guessed: 33, Total: 33
# Metrics(tp=33, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 22 ##############
# Label Tokens:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Messenger'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# prediction Bacakanlah/O (/O sampaikanlah/O wahai/O Nabi/O Muhammad/Messenger )/O kepada/O mereka/O berita/O penting/O (/O tentang/O )/O Nuh/Messenger ketika/O dia/O berkata/O kepada/O kaumnya/O ,/O “/O Wahai/O kaumku/O ,/O jika/O terasa/O berat/O bagi/O kamu/O keberadaanku/O tinggal/O (/O bersamamu/O )/O dan/O peringatanku/O dengan/O ayat-ayat/O Allah/Allah ,/O kepada/O Allahlah/O aku/O bertawakal/O ./O
# Prediction Tokens:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Messenger'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# correct:
#  [('Bacakanlah', 'O'), ('(', 'O'), ('sampaikanlah', 'O'), ('wahai', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('berita', 'O'), ('penting', 'O'), ('(', 'O'), ('tentang', 'O'), (')', 'O'), ('Nuh', 'Messenger'), ('ketika', 'O'), ('dia', 'O'), ('berkata', 'O'), ('kepada', 'O'), ('kaumnya', 'O'), (',', 'O'), ('“', 'O'), ('Wahai', 'O'), ('kaumku', 'O'), (',', 'O'), ('jika', 'O'), ('terasa', 'O'), ('berat', 'O'), ('bagi', 'O'), ('kamu', 'O'), ('keberadaanku', 'O'), ('tinggal', 'O'), ('(', 'O'), ('bersamamu', 'O'), (')', 'O'), ('dan', 'O'), ('peringatanku', 'O'), ('dengan', 'O'), ('ayat-ayat', 'O'), ('Allah', 'Allah'), (',', 'O'), ('kepada', 'O'), ('Allahlah', 'O'), ('aku', 'O'), ('bertawakal', 'O'), ('.', 'O')]
# Correct: 46, Guessed: 46, Total: 46
# Metrics(tp=46, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 23 ##############
# Label Tokens:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# prediction Oleh/O karena/O itu/O ,/O bulatkanlah/O keputusanmu/O dan/O kumpulkanlah/O sekutu-sekutumu/O (/O untuk/O membinasakanku/O )/O ,/O selanjutnya/O janganlah/O keputusanmu/O itu/O dirahasiakan/O ./O
# Prediction Tokens:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# correct:
#  [('Oleh', 'O'), ('karena', 'O'), ('itu', 'O'), (',', 'O'), ('bulatkanlah', 'O'), ('keputusanmu', 'O'), ('dan', 'O'), ('kumpulkanlah', 'O'), ('sekutu-sekutumu', 'O'), ('(', 'O'), ('untuk', 'O'), ('membinasakanku', 'O'), (')', 'O'), (',', 'O'), ('selanjutnya', 'O'), ('janganlah', 'O'), ('keputusanmu', 'O'), ('itu', 'O'), ('dirahasiakan', 'O'), ('.', 'O')]
# Correct: 20, Guessed: 20, Total: 20
# Metrics(tp=20, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 24 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# prediction Kemudian/O ,/O bertindaklah/O terhadap/O diriku/O dan/O janganlah/O kamu/O tunda-tunda/O (/O tindakan/O itu/O )/O kepadaku/O ./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('bertindaklah', 'O'), ('terhadap', 'O'), ('diriku', 'O'), ('dan', 'O'), ('janganlah', 'O'), ('kamu', 'O'), ('tunda-tunda', 'O'), ('(', 'O'), ('tindakan', 'O'), ('itu', 'O'), (')', 'O'), ('kepadaku', 'O'), ('.', 'O')]
# Correct: 15, Guessed: 15, Total: 15
# Metrics(tp=15, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 25 ##############
# Label Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# prediction Jika/O kamu/O berpaling/O (/O dari/O peringatanku/O )/O ,/O aku/O tidak/O meminta/O imbalan/O sedikit/O pun/O darimu/O ./O
# Prediction Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# correct:
#  [('Jika', 'O'), ('kamu', 'O'), ('berpaling', 'O'), ('(', 'O'), ('dari', 'O'), ('peringatanku', 'O'), (')', 'O'), (',', 'O'), ('aku', 'O'), ('tidak', 'O'), ('meminta', 'O'), ('imbalan', 'O'), ('sedikit', 'O'), ('pun', 'O'), ('darimu', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 16, Total: 16
# Metrics(tp=16, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 26 ##############
# Label Tokens:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# prediction Imbalanku/O tidak/O lain/O hanyalah/O dari/O Allah/Allah dan/O aku/O diperintah/O agar/O aku/O masuk/O ke/O dalam/O golongan/O orang-orang/O muslim/O ./O
# Prediction Tokens:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# correct:
#  [('Imbalanku', 'O'), ('tidak', 'O'), ('lain', 'O'), ('hanyalah', 'O'), ('dari', 'O'), ('Allah', 'Allah'), ('dan', 'O'), ('aku', 'O'), ('diperintah', 'O'), ('agar', 'O'), ('aku', 'O'), ('masuk', 'O'), ('ke', 'O'), ('dalam', 'O'), ('golongan', 'O'), ('orang-orang', 'O'), ('muslim', 'O'), ('.', 'O')]
# Correct: 18, Guessed: 18, Total: 18
# Metrics(tp=18, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 27 ##############
# Label Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('.', 'O')]
# prediction ”/O Mereka/O mendustakannya/O (/O Nuh/Messenger )/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Mereka', 'O'), ('mendustakannya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('.', 'O')]
# Correct: 7, Guessed: 7, Total: 7
# Metrics(tp=7, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 28 ##############
# Label Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# prediction Lalu/O ,/O Kami/O selamatkan/O dia/O dan/O orang-orang/O yang/O bersamanya/O di/O dalam/O bahtera/O serta/O Kami/O jadikan/O mereka/O sebagai/O generasi/O penerus/O dan/O Kami/O tenggelamkan/O orang-orang/O yang/O mendustakan/O ayat-ayat/O Kami/O ./O
# Prediction Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# correct:
#  [('Lalu', 'O'), (',', 'O'), ('Kami', 'O'), ('selamatkan', 'O'), ('dia', 'O'), ('dan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('bersamanya', 'O'), ('di', 'O'), ('dalam', 'O'), ('bahtera', 'O'), ('serta', 'O'), ('Kami', 'O'), ('jadikan', 'O'), ('mereka', 'O'), ('sebagai', 'O'), ('generasi', 'O'), ('penerus', 'O'), ('dan', 'O'), ('Kami', 'O'), ('tenggelamkan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('mendustakan', 'O'), ('ayat-ayat', 'O'), ('Kami', 'O'), ('.', 'O')]
# Correct: 28, Guessed: 28, Total: 28
# Metrics(tp=28, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 29 ##############
# Label Tokens:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# prediction Perhatikanlah/O bagaimana/O kesudahan/O orang-orang/O yang/O diberi/O peringatan/O itu/O ./O
# Prediction Tokens:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# correct:
#  [('Perhatikanlah', 'O'), ('bagaimana', 'O'), ('kesudahan', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('diberi', 'O'), ('peringatan', 'O'), ('itu', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 9, Total: 9
# Metrics(tp=9, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 30 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# prediction Kemudian/O ,/O Kami/O mengutus/O setelahnya/O (/O Nuh/Messenger )/O beberapa/O rasul/O kepada/O kaum/O mereka/O (/O umat/O masing-masing/O )/O ,/O maka/O rasul-rasul/O itu/O datang/O kepada/O mereka/O dengan/O membawa/O bukti-bukti/O yang/O nyata/O ,/O tetapi/O mereka/O tidak/O mau/O beriman/O karena/O mereka/O dahulu/O telah/O (/O biasa/O )/O mendustakannya/O ./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('setelahnya', 'O'), ('(', 'O'), ('Nuh', 'Messenger'), (')', 'O'), ('beberapa', 'O'), ('rasul', 'O'), ('kepada', 'O'), ('kaum', 'O'), ('mereka', 'O'), ('(', 'O'), ('umat', 'O'), ('masing-masing', 'O'), (')', 'O'), (',', 'O'), ('maka', 'O'), ('rasul-rasul', 'O'), ('itu', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('bukti-bukti', 'O'), ('yang', 'O'), ('nyata', 'O'), (',', 'O'), ('tetapi', 'O'), ('mereka', 'O'), ('tidak', 'O'), ('mau', 'O'), ('beriman', 'O'), ('karena', 'O'), ('mereka', 'O'), ('dahulu', 'O'), ('telah', 'O'), ('(', 'O'), ('biasa', 'O'), (')', 'O'), ('mendustakannya', 'O'), ('.', 'O')]
# Correct: 44, Guessed: 44, Total: 44
# Metrics(tp=44, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 31 ##############
# Label Tokens:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# prediction Demikianlah/O Kami/O mengunci/O hati/O orang-orang/O yang/O melampaui/O batas/O ./O
# Prediction Tokens:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# correct:
#  [('Demikianlah', 'O'), ('Kami', 'O'), ('mengunci', 'O'), ('hati', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('melampaui', 'O'), ('batas', 'O'), ('.', 'O')]
# Correct: 9, Guessed: 9, Total: 9
# Metrics(tp=9, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 32 ##############
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'HistoricPerson'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# prediction Kemudian/O ,/O setelah/O mereka/O Kami/O mengutus/O Musa/Messenger dan/O Harun/Prophet kepada/O Fir‘aun/HistoricPerson dan/O para/O pemuka/O kaumnya/O ,/O dengan/O membawa/O tanda-tanda/O (/O kekuasaan/O )/O Kami/O ./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'HistoricPerson'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('setelah', 'O'), ('mereka', 'O'), ('Kami', 'O'), ('mengutus', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), ('kepada', 'O'), ('Fir‘aun', 'HistoricPerson'), ('dan', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (',', 'O'), ('dengan', 'O'), ('membawa', 'O'), ('tanda-tanda', 'O'), ('(', 'O'), ('kekuasaan', 'O'), (')', 'O'), ('Kami', 'O'), ('.', 'O')]
# Correct: 24, Guessed: 24, Total: 24
# Metrics(tp=24, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 33 ##############
# Label Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# prediction Lalu/O ,/O mereka/O menyombongkan/O diri/O dan/O mereka/O adalah/O kaum/O pendurhaka/O ./O
# Prediction Tokens:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# correct:
#  [('Lalu', 'O'), (',', 'O'), ('mereka', 'O'), ('menyombongkan', 'O'), ('diri', 'O'), ('dan', 'O'), ('mereka', 'O'), ('adalah', 'O'), ('kaum', 'O'), ('pendurhaka', 'O'), ('.', 'O')]
# Correct: 11, Guessed: 11, Total: 11
# Metrics(tp=11, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 34 ##############
# Label Tokens:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# prediction Ketika/O telah/O datang/O kepada/O mereka/O kebenaran/O (/O mukjizat/O )/O dari/O sisi/O Kami/O ,/O mereka/O berkata/O ,/O “/O Sesungguhnya/O ini/O benar-benar/O sihir/O yang/O nyata/O ./O
# Prediction Tokens:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# correct:
#  [('Ketika', 'O'), ('telah', 'O'), ('datang', 'O'), ('kepada', 'O'), ('mereka', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('dari', 'O'), ('sisi', 'O'), ('Kami', 'O'), (',', 'O'), ('mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Sesungguhnya', 'O'), ('ini', 'O'), ('benar-benar', 'O'), ('sihir', 'O'), ('yang', 'O'), ('nyata', 'O'), ('.', 'O')]
# Correct: 24, Guessed: 24, Total: 24
# Metrics(tp=24, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 35 ##############
# Label Tokens:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# prediction ”/O Musa/Messenger berkata/O ,/O “/O Apakah/O (/O pantas/O )/O kamu/O mengatakan/O terhadap/O kebenaran/O (/O mukjizat/O )/O ketika/O ia/O datang/O kepadamu/O ,/O ‘sihirkah/O ini/O ?/O ’/O Padahal/O ,/O para/O penyihir/O itu/O tidaklah/O mendapat/O kemenangan/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('(', 'O'), ('pantas', 'O'), (')', 'O'), ('kamu', 'O'), ('mengatakan', 'O'), ('terhadap', 'O'), ('kebenaran', 'O'), ('(', 'O'), ('mukjizat', 'O'), (')', 'O'), ('ketika', 'O'), ('ia', 'O'), ('datang', 'O'), ('kepadamu', 'O'), (',', 'O'), ('‘sihirkah', 'O'), ('ini', 'O'), ('?', 'O'), ('’', 'O'), ('Padahal', 'O'), (',', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('tidaklah', 'O'), ('mendapat', 'O'), ('kemenangan', 'O'), ('.', 'O')]
# Correct: 34, Guessed: 34, Total: 34
# Metrics(tp=34, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 36 ##############
# uncover negeri
# Label Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Prophet'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('(', 'O'), ('negeri', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# prediction ”/O Mereka/O berkata/O ,/O “/O Apakah/O engkau/O (/O Musa/Messenger )/O datang/O kepada/O kami/O untuk/O memalingkan/O kami/O dari/O apa/O yang/O kami/O dapati/O pada/O nenek/O moyang/O kami/O (/O menyembah/O berhala/O )/O ,/O dan/O agar/O kamu/O berdua/O (/O Musa/Messenger dan/O Harun/Messenger )/O mempunyai/O kekuasaan/O di/O bumi/AstronomicalBody (/O negeri Mesir/GeographicalLocation )/O ?/O Kami/O tidak/O akan/O beriman/O kepada/O kamu/O berdua/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), ('Harun', 'Messenger'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('(', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Mereka', 'O'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apakah', 'O'), ('engkau', 'O'), ('(', 'O'), ('Musa', 'Messenger'), (')', 'O'), ('datang', 'O'), ('kepada', 'O'), ('kami', 'O'), ('untuk', 'O'), ('memalingkan', 'O'), ('kami', 'O'), ('dari', 'O'), ('apa', 'O'), ('yang', 'O'), ('kami', 'O'), ('dapati', 'O'), ('pada', 'O'), ('nenek', 'O'), ('moyang', 'O'), ('kami', 'O'), ('(', 'O'), ('menyembah', 'O'), ('berhala', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('agar', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('(', 'O'), ('Musa', 'Messenger'), ('dan', 'O'), (')', 'O'), ('mempunyai', 'O'), ('kekuasaan', 'O'), ('di', 'O'), ('bumi', 'AstronomicalBody'), ('(', 'O'), ('Mesir', 'GeographicalLocation'), (')', 'O'), ('?', 'O'), ('Kami', 'O'), ('tidak', 'O'), ('akan', 'O'), ('beriman', 'O'), ('kepada', 'O'), ('kamu', 'O'), ('berdua', 'O'), ('.', 'O')]
# Correct: 54, Guessed: 55, Total: 56
# Metrics(tp=54, fp=1, fn=2, prec=0.9818181818181818, rec=0.9642857142857143, fscore=0.972972972972973)
# ######### Instance 37 ##############
# Label Tokens:
#  [('”', 'O'), ('Fir‘aun', 'HistoricPerson'), ('berkata', 'O'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O'), ('!', 'O'), ('”', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('“', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O'), ('!', 'O'), ('”', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(', 'O'), ('tali-temali', 'O'), (')', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O'), ('.', 'O')]
# prediction ”/O Fir‘aun/HistoricPerson berkata/O (/O kepada/O para/O pemuka/O kaumnya/O )/O ,/O “/O Datangkanlah/O kepadaku/O semua/O penyihir/O yang/O ulung/O !/O ”/O Ketika/O para/O penyihir/O itu/O datang/O ,/O Musa/Messenger berkata/O kepada/O mereka/O ,/O “/O Lemparkanlah/O apa/O yang/O hendak/O kamu/O lemparkan/O !/O ”/O Setelah/O mereka/O melemparkan/O (/O tali-temali/O )/O ,/O Musa/Messenger berkata/O ,/O “/O Apa/O yang/O kamu/O bawa/O itulah/O sihir/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Fir‘aun', 'HistoricPerson'), ('berkata', 'O'), ('(', 'O'), ('kepada', 'O'), ('para', 'O'), ('pemuka', 'O'), ('kaumnya', 'O'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Datangkanlah', 'O'), ('kepadaku', 'O'), ('semua', 'O'), ('penyihir', 'O'), ('yang', 'O'), ('ulung', 'O'), ('!', 'O'), ('”', 'O'), ('Ketika', 'O'), ('para', 'O'), ('penyihir', 'O'), ('itu', 'O'), ('datang', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), ('kepada', 'O'), ('mereka', 'O'), (',', 'O'), ('“', 'O'), ('Lemparkanlah', 'O'), ('apa', 'O'), ('yang', 'O'), ('hendak', 'O'), ('kamu', 'O'), ('lemparkan', 'O'), ('!', 'O'), ('”', 'O'), ('Setelah', 'O'), ('mereka', 'O'), ('melemparkan', 'O'), ('(', 'O'), ('tali-temali', 'O'), (')', 'O'), (',', 'O'), ('Musa', 'Messenger'), ('berkata', 'O'), (',', 'O'), ('“', 'O'), ('Apa', 'O'), ('yang', 'O'), ('kamu', 'O'), ('bawa', 'O'), ('itulah', 'O'), ('sihir', 'O'), ('.', 'O')]
# correct:
# ...
# Correct: 11, Guessed: 11, Total: 11
# Metrics(tp=11, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 301 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Ibrahim', 'Messenger'), ('adalah', 'O'), ('imam', 'O'), ('(', 'O'), ('sosokanutan', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (',', 'O'), ('hanif', 'O'), ('(', 'O'), ('lurus', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Ibrahim/Messenger adalah/O imam/O (/O sosokanutan/O )/O yang/O patuh/O kepada/O Allah/Allah ,/O hanif/O (/O lurus/O )/O ,/O dan/O bukan/O termasuk/O orang-orang/O musyrik/O ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Ibrahim', 'Messenger'), ('adalah', 'O'), ('imam', 'O'), ('(', 'O'), ('sosokanutan', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (',', 'O'), ('hanif', 'O'), ('(', 'O'), ('lurus', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('Ibrahim', 'Messenger'), ('adalah', 'O'), ('imam', 'O'), ('(', 'O'), ('sosokanutan', 'O'), (')', 'O'), ('yang', 'O'), ('patuh', 'O'), ('kepada', 'O'), ('Allah', 'Allah'), (',', 'O'), ('hanif', 'O'), ('(', 'O'), ('lurus', 'O'), (')', 'O'), (',', 'O'), ('dan', 'O'), ('bukan', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# Correct: 23, Guessed: 23, Total: 23
# Metrics(tp=23, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 302 ##############
# Label Tokens:
#  [('(', 'O'), ('Ibrahim', 'Messenger'), (')', 'O'), ('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('(', 'O'), ('dan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# prediction (/O Ibrahim/Messenger )/O bersyukur/O atas/O nikmat-nikmat-Nya/O (/O dan/O Allah/Allah )/O telah/O memilih/O serta/O menunjukinya/O ke/O jalan/O yang/O lurus/O ./O
# Prediction Tokens:
#  [('(', 'O'), ('Ibrahim', 'Messenger'), (')', 'O'), ('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('(', 'O'), ('dan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# correct:
#  [('(', 'O'), ('Ibrahim', 'Messenger'), (')', 'O'), ('bersyukur', 'O'), ('atas', 'O'), ('nikmat-nikmat-Nya', 'O'), ('(', 'O'), ('dan', 'O'), ('Allah', 'Allah'), (')', 'O'), ('telah', 'O'), ('memilih', 'O'), ('serta', 'O'), ('menunjukinya', 'O'), ('ke', 'O'), ('jalan', 'O'), ('yang', 'O'), ('lurus', 'O'), ('.', 'O')]
# Correct: 19, Guessed: 19, Total: 19
# Metrics(tp=19, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 303 ##############
# Label Tokens:
#  [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('akhirat', 'O'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# prediction Kami/O berikan/O kepadanya/O kebaikan/O di/O dunia/O dan/O sesungguhnya/O di/O akhirat/O dia/O termasuk/O orang-orang/O yang/O saleh/O ./O
# Prediction Tokens:
#  [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('akhirat', 'O'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# correct:
#  [('Kami', 'O'), ('berikan', 'O'), ('kepadanya', 'O'), ('kebaikan', 'O'), ('di', 'O'), ('dunia', 'O'), ('dan', 'O'), ('sesungguhnya', 'O'), ('di', 'O'), ('akhirat', 'O'), ('dia', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('saleh', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 16, Total: 16
# Metrics(tp=16, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 304 ##############
# uncover agama
# uncover agama
# Label Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Ikutilah', 'O'), ('Ibrahim', 'Religion'), ('sebagai', 'O'), ('(', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# prediction Kemudian/O ,/O Kami/O wahyukan/O kepadamu/O (/O Nabi/O Muhammad/Messenger )/O ,/O “/O Ikutilah/O agama Ibrahim/Religion sebagai/O (/O sosok/O )/O yang/O hanif/O dan/O tidak/O termasuk/O orang-orang/O musyrik/O ./O
# Prediction Tokens:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Ikutilah', 'O'), ('Ibrahim', 'Religion'), ('sebagai', 'O'), ('(', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# correct:
#  [('Kemudian', 'O'), (',', 'O'), ('Kami', 'O'), ('wahyukan', 'O'), ('kepadamu', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), (',', 'O'), ('“', 'O'), ('Ikutilah', 'O'), ('Ibrahim', 'Religion'), ('sebagai', 'O'), ('(', 'O'), ('sosok', 'O'), (')', 'O'), ('yang', 'O'), ('hanif', 'O'), ('dan', 'O'), ('tidak', 'O'), ('termasuk', 'O'), ('orang-orang', 'O'), ('musyrik', 'O'), ('.', 'O')]
# Correct: 25, Guessed: 25, Total: 25
# Metrics(tp=25, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 305 ##############
# uncover hari
# uncover hari
# Label Tokens:
#  [('”', 'O'), ('Sesungguhnya', 'O'), ('(', 'O'), ('mengagungkan', 'O'), (')', 'O'), ('Sabtu', 'CalendarEvent'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'HistoricPeople'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# prediction ”/O Sesungguhnya/O (/O mengagungkan/O )/O hari Sabtu/CalendarEvent hanya/O diwajibkan/O bagi/O orang-orang/O (/O Yahudi/HistoricPeople )/O yang/O memperselisihkannya/O ./O
# Prediction Tokens:
#  [('”', 'O'), ('Sesungguhnya', 'O'), ('(', 'O'), ('mengagungkan', 'O'), (')', 'O'), ('Sabtu', 'CalendarEvent'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'HistoricPeople'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# correct:
#  [('”', 'O'), ('Sesungguhnya', 'O'), ('(', 'O'), ('mengagungkan', 'O'), (')', 'O'), ('Sabtu', 'CalendarEvent'), ('hanya', 'O'), ('diwajibkan', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('(', 'O'), ('Yahudi', 'HistoricPeople'), (')', 'O'), ('yang', 'O'), ('memperselisihkannya', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 16, Total: 16
# Metrics(tp=16, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 306 ##############
# uncover hari
# uncover hari
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('Kiamat', 'AfterLifeEvent'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Tuhanmu/O benar-benar/O akan/O memberi/O keputusan/O di/O antara/O mereka/O pada/O hari Kiamat/AfterLifeEvent tentang/O apa/O yang/O mereka/O perselisihkan/O ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('Kiamat', 'AfterLifeEvent'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('benar-benar', 'O'), ('akan', 'O'), ('memberi', 'O'), ('keputusan', 'O'), ('di', 'O'), ('antara', 'O'), ('mereka', 'O'), ('pada', 'O'), ('Kiamat', 'AfterLifeEvent'), ('tentang', 'O'), ('apa', 'O'), ('yang', 'O'), ('mereka', 'O'), ('perselisihkan', 'O'), ('.', 'O')]
# Correct: 17, Guessed: 17, Total: 17
# Metrics(tp=17, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 307 ##############
# Label Tokens:
#  [('Serulah', 'O'), ('(', 'O'), ('manusia', 'O'), (')', 'O'), ('ke', 'O'), ('jalan', 'O'), ('Tuhanmu', 'O'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# prediction Serulah/O (/O manusia/O )/O ke/O jalan/O Tuhanmu/O dengan/O hikmah/O dan/O pengajaran/O yang/O baik/O serta/O debatlah/O mereka/O dengan/O cara/O yang/O lebih/O baik/O ./O
# Prediction Tokens:
#  [('Serulah', 'O'), ('(', 'O'), ('manusia', 'O'), (')', 'O'), ('ke', 'O'), ('jalan', 'O'), ('Tuhanmu', 'O'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# correct:
#  [('Serulah', 'O'), ('(', 'O'), ('manusia', 'O'), (')', 'O'), ('ke', 'O'), ('jalan', 'O'), ('Tuhanmu', 'O'), ('dengan', 'O'), ('hikmah', 'O'), ('dan', 'O'), ('pengajaran', 'O'), ('yang', 'O'), ('baik', 'O'), ('serta', 'O'), ('debatlah', 'O'), ('mereka', 'O'), ('dengan', 'O'), ('cara', 'O'), ('yang', 'O'), ('lebih', 'O'), ('baik', 'O'), ('.', 'O')]
# Correct: 22, Guessed: 22, Total: 22
# Metrics(tp=22, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 308 ##############
# Label Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Dialah', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# prediction Sesungguhnya/O Tuhanmu/O Dialah/O yang/O paling/O tahu/O siapa/O yang/O tersesat/O dari/O jalan-Nya/O dan/O Dia/O (/O pula/O )/O yang/O paling/O tahu/O siapa/O yang/O mendapat/O petunjuk/O ./O
# Prediction Tokens:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Dialah', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# correct:
#  [('Sesungguhnya', 'O'), ('Tuhanmu', 'O'), ('Dialah', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('tersesat', 'O'), ('dari', 'O'), ('jalan-Nya', 'O'), ('dan', 'O'), ('Dia', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('yang', 'O'), ('paling', 'O'), ('tahu', 'O'), ('siapa', 'O'), ('yang', 'O'), ('mendapat', 'O'), ('petunjuk', 'O'), ('.', 'O')]
# Correct: 24, Guessed: 24, Total: 24
# Metrics(tp=24, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 309 ##############
# Label Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# prediction Jika/O kamu/O membalas/O ,/O balaslah/O dengan/O (/O balasan/O )/O yang/O sama/O dengan/O siksaan/O yang/O ditimpakan/O kepadamu/O ./O
# Prediction Tokens:
#  [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# correct:
#  [('Jika', 'O'), ('kamu', 'O'), ('membalas', 'O'), (',', 'O'), ('balaslah', 'O'), ('dengan', 'O'), ('(', 'O'), ('balasan', 'O'), (')', 'O'), ('yang', 'O'), ('sama', 'O'), ('dengan', 'O'), ('siksaan', 'O'), ('yang', 'O'), ('ditimpakan', 'O'), ('kepadamu', 'O'), ('.', 'O')]
# Correct: 17, Guessed: 17, Total: 17
# Metrics(tp=17, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 310 ##############
# Label Tokens:
#  [('Sungguh', 'O'), (',', 'O'), ('jika', 'O'), ('kamu', 'O'), ('bersabar', 'O'), (',', 'O'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# prediction Sungguh/O ,/O jika/O kamu/O bersabar/O ,/O hal/O itu/O benar-benar/O lebih/O baik/O bagi/O orang-orang/O yang/O sabar/O ./O
# Prediction Tokens:
#  [('Sungguh', 'O'), (',', 'O'), ('jika', 'O'), ('kamu', 'O'), ('bersabar', 'O'), (',', 'O'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# correct:
#  [('Sungguh', 'O'), (',', 'O'), ('jika', 'O'), ('kamu', 'O'), ('bersabar', 'O'), (',', 'O'), ('hal', 'O'), ('itu', 'O'), ('benar-benar', 'O'), ('lebih', 'O'), ('baik', 'O'), ('bagi', 'O'), ('orang-orang', 'O'), ('yang', 'O'), ('sabar', 'O'), ('.', 'O')]
# Correct: 16, Guessed: 16, Total: 16
# Metrics(tp=16, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# ######### Instance 311 ##############
# Label Tokens:
#  [('Bersabarlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('(', 'O'), ('pertolongan', 'O'), (')', 'O'), ('Allah', 'Allah'), (',', 'O'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('(', 'O'), ('kekufuran', 'O'), (')', 'O'), ('mereka', 'O'), (',', 'O'), ('dan', 'O'), ('jangan', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# prediction Bersabarlah/O (/O Nabi/O Muhammad/Messenger )/O dan/O kesabaranmu/O itu/O semata-mata/O dengan/O (/O pertolongan/O )/O Allah/Allah ,/O janganlah/O bersedih/O terhadap/O (/O kekufuran/O )/O mereka/O ,/O dan/O jangan/O (/O pula/O )/O bersempit/O dada/O terhadap/O tipu/O daya/O yang/O mereka/O rencanakan/O ./O
# Prediction Tokens:
#  [('Bersabarlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('(', 'O'), ('pertolongan', 'O'), (')', 'O'), ('Allah', 'Allah'), (',', 'O'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('(', 'O'), ('kekufuran', 'O'), (')', 'O'), ('mereka', 'O'), (',', 'O'), ('dan', 'O'), ('jangan', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# correct:
#  [('Bersabarlah', 'O'), ('(', 'O'), ('Nabi', 'O'), ('Muhammad', 'Messenger'), (')', 'O'), ('dan', 'O'), ('kesabaranmu', 'O'), ('itu', 'O'), ('semata-mata', 'O'), ('dengan', 'O'), ('(', 'O'), ('pertolongan', 'O'), (')', 'O'), ('Allah', 'Allah'), (',', 'O'), ('janganlah', 'O'), ('bersedih', 'O'), ('terhadap', 'O'), ('(', 'O'), ('kekufuran', 'O'), (')', 'O'), ('mereka', 'O'), (',', 'O'), ('dan', 'O'), ('jangan', 'O'), ('(', 'O'), ('pula', 'O'), (')', 'O'), ('bersempit', 'O'), ('dada', 'O'), ('terhadap', 'O'), ('tipu', 'O'), ('daya', 'O'), ('yang', 'O'), ('mereka', 'O'), ('rencanakan', 'O'), ('.', 'O')]
# Correct: 37, Guessed: 37, Total: 37
# Metrics(tp=37, fp=0, fn=0, prec=1.0, rec=1.0, fscore=1.0)
# Total records in the test set: 311
# Average Precision: 0.9985166549924447
# Average Recall: 0.9980432716412476
# Average F1 Score: 0.998263600845398
